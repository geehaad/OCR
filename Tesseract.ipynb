# %%
import cv2
import pytesseract
import matplotlib.pyplot as plt
from IPython.display import Image
from pylab import rcParams
import numpy as np
from pprint import pprint
from pytesseract import Output

# %%
img = cv2.imread('img1.jpeg')

# %%
plt.imshow(img)

# %%
text1 = pytesseract.image_to_string('img1.jpeg', lang="ara")


print(text1)
# Out:
# "ها هي» اقرأها بنفسك". رد بيتر إيفانوفيتش» وهو يسلم فيدور
# الجريدة التى ما تزال رطبة من ضغطه عليها. كانت الكلمات محاطةً

# %%
img2 = cv2.imread('img2.jpeg')
plt.imshow(img2)

# %%
text2 = pytesseract.image_to_string('img2.jpeg', lang="ara")


print(text2)
# Out:
# الجريدة

# %%
img3 = cv2.imread('img3.jpeg')
plt.imshow(img3)

# %%
text3 = pytesseract.image_to_string('img3.jpeg', lang="ara")


print(text3)
# Out:
# "كلأ لا تقل ذلك!"

# %%
img4 = cv2.imread('img4.jpeg')
plt.imshow(img4)

# %%
text4 = pytesseract.image_to_string('img4.jpeg', lang="ara")


print(text4)
# Out:
# "أيها السادة". قال» "لقد مات إيان إيليتش!"
# "كلأ لا تقل ذلك!"
#
# "ها هي» اقرأها بنفسك". رد بيتر إيفانوفيتش» وهو يسلم فيدور
# الجريدة التى ما تزال رطبة من ضغطه عليها. كانت الكلمات محاطةً

# %%
img4 = cv2.imread('img5.jpeg')
plt.imshow(img5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-57ed11e7aaf0> in <module>
#       1 img4 = cv2.imread('img5.jpeg')
# ----> 2 plt.imshow(img5)
#
# NameError: name 'img5' is not defined

# %%
text5 = pytesseract.image_to_string('img5.jpeg', lang="ara")


print(text5)
# Out:
# |]
#
# أثناء الاستراحة في محاكمة ميلفينسكي- بمجمّع المحاكم الضخم
# التقى المدعوون المدنيون والأعضاء في حجرة إيجوروفيتش شيبيك
# الخاصة» حيث دار الحوار حول قضية كارسوفسكى الشهيرة. ذكر يدور
# فازيليفيتش بلباقة أنها غير خاضعة لنطاق محكمته؛ وقال إيفان
# إيجوروفيتش العكس ؛ بينما لم يتخذ بيتر إيفانوفيتش أي موقف- حيث لم
# يشارك منذ البداية في الحوار واكتفى بالنظر في جريدة الجازيت التي
# استلمها للتو:
#
# "أيها السادة". قال» "لقد مات إيقان إيليتش!"
#
# "كلأ لا تقل ذلك!"
#
# "ها هيء اقرأها بنفسك". رد بيتر إيفانوفيتش» وهو يسلم فيدور
# الجريدة التي ما تزال رطبة من ضغطه عليها. كانت الكلمات محاطة
#
# 21
