# %% [markdown]
# <a href="https://colab.research.google.com/github/geehaad/OCR/blob/main/Copy_of_EasyOCR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Arabic

# %%
# !pip install easyocr

# %%
import matplotlib.pyplot as plt
import cv2
import easyocr
from pylab import rcParams
from IPython.display import Image
rcParams['figure.figsize'] = 8, 16

# %%
reader = easyocr.Reader(['en'])

# %%
Image("img5.jpg")

# %%
output = reader.readtext("img5.jpg")
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)

# %%
output
# Out:
# [[[[188, 493], [636, 493], [636, 546], [188, 546]],
#   'أثناء الاستراحة فيمحاكمة ميلفينسكي - بمجمع',
#   0.5516863157655122],
#  [[[24, 548], [104, 548], [104, 580], [24, 580]], 'شيبيك', 0.9896216112789935],
#  [[[151, 540], [605, 540], [605, 584], [151, 584]],
#   'المدعوون المدنيون والأعضاءفي حجرة إيجورو',
#   0.4929116483541456],
#  [[[21, 587], [667, 587], [667, 630], [21, 630]],
#   'الخاصة  حبث دارالحوار حول قضية كارسوفسكى الشهيرة. ذكر فيدور',
#   0.41128181658305696],
#  [[[23, 633], [147, 633], [147, 669], [23, 669]],
#   'وقال إيفان',
#   0.49856943877557375],
#  [[[158, 633], [391, 633], [391, 669], [158, 669]],
#   'خاضعة لنطاق محكمنه',
#   0.8742973703136349],
#  [[[440, 627], [671, 627], [671, 675], [440, 675]],
#   'فازيليفيتش بلباقة أنها',
#   0.9433661029038635],
#  [[[25, 675], [349, 675], [349, 718], [25, 718]],
#   'بيتر إيفانوفيتش أي موقف - حبث م',
#   0.44520020840218033],
#  [[[417, 678], [470, 678], [470, 714], [417, 714]],
#   'ببنما',
# ...

# %%
Image("img4.jpg")

# %%
output2 = reader.readtext("img4.jpg")

# %%
output2
# Out:
# [[[[223, 15], [243, 15], [243, 39], [223, 39]], '"!', 0.9862712880286126],
#  [[[233, 11], [449, 11], [449, 52], [233, 52]],
#   '"لقد مات إبفان إيليتش !',
#   0.7147549132093036],
#  [[[464, 14], [502, 14], [502, 44], [464, 44]], 'قال', 0.7492001625674864],
#  [[[523, 11], [633, 11], [633, 47], [523, 47]],
#   '"أيها السادةا',
#   0.6256338205625184],
#  [[[439, 68], [571, 68], [571, 109], [439, 109]],
#   'لا تقل ذلك !"',
#   0.8117793522290139],
#  [[[585, 65], [635, 65], [635, 103], [585, 103]], 'اكلاً', 0.5790134179446439],
#  [[[21, 128], [191, 128], [191, 171], [21, 171]],
#   'وهويسلم فيدور',
#   0.9057325241760187],
#  [[[203, 127], [633, 127], [633, 169], [203, 169]],
#   '"هاهي ء اقرأها بنفسك " رد بيتر إيفانوفيتشر',
#   0.43313269603770277],
#  [[[22, 166], [670, 166], [670, 214], [22, 214]],
#   'الجريدة الني ماتزال رطبة من ضغطه عليها. كانت الكلمات محاطة',
#   0.7334942689013099]]

# %%
Image("img3.jpg")

# %%
output3 = reader.readtext("img3.jpg")

# %%
output3
# Out:
# [[[[61, 25], [255, 25], [255, 69], [61, 69]],
#   '"كلا ، لا تقل ذلك !"',
#   0.38839990098150784]]

# %%
Image("img2.jpg")

# %%
output2 = reader.readtext("img2.jpg")

# %%
output2
# Out:
# [[[[0, 22], [64, 22], [64, 54], [0, 54]], 'لجريدة', 0.9390736955276817]]

# %%
Image("img1.jpg")

# %%
output1 = reader.readtext("img1.jpg")

# %%
output1
# Out:
# [[[[21, 10], [264, 10], [264, 53], [21, 53]],
#   'فيتثر   وهويسلم فيدور',
#   0.6271388429714466],
#  [[[311, 9], [633, 9], [633, 49], [311, 49]],
#   '"هاهي  اقرأها بنفسك " ، رد بيتر',
#   0.46844842377109863],
#  [[[23, 51], [669, 51], [669, 95], [23, 95]],
#   'الجريدة التي ماتزال رطبة من ضغطه عليها. كانت الكلمات محاطة',
#   0.3067390261307956],
#  [[[251.46153846153845, 13.307692307692308],
#    [311.2887687665751, 8.723160084678767],
#    [313.53846153846155, 44.69230769230769],
#    [252.71123123342488, 49.27683991532123]],
#   'إيفانو',
#   0.5898367383980616]]

# %% [markdown]
# # English

# %%
Image("eng1.jpeg")

# %%
out1 = reader.readtext("eng1.jpeg")
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)

# %%
out1
# Out:
# [[[[182, 160], [302, 160], [302, 214], [182, 214]], 'THE', 0.7571936173940235],
#  [[[184, 226], [396, 226], [396, 280], [184, 280]],
#   'ART OF',
#   0.9881058728553731],
#  [[[181, 289], [507, 289], [507, 345], [181, 345]],
#   'STATISTICS',
#   0.9655146771340087],
#  [[[182, 407], [489, 407], [489, 447], [182, 447]],
#   'HOW To LEARN',
#   0.5779671411554665],
#  [[[180, 461], [302, 461], [302, 499], [180, 499]],
#   'FROM',
#   0.9664027094841003],
#  [[[313, 463], [419, 463], [419, 499], [313, 499]],
#   'DATA',
#   0.6264267196323314],
#  [[[184, 573], [527, 573], [527, 606], [184, 606]],
#   'DAVID SPIEGELHALTER',
#   0.837598722475812],
#  [[[289, 809], [421, 809], [421, 829], [289, 829]],
#   'BASIC BUOKS',
#   0.7144042024419123],
#  [[[327, 835], [387, 835], [387, 849], [327, 849]],
#   'Neir Yora',
#   0.16161280550634655]]

# %%
Image("eng2.jpeg")

# %%
out2 = reader.readtext("eng2.jpeg")

# %%
out2
# Out:
# [[[[86, 132], [634, 132], [634, 163], [86, 163]],
#   'To statisticians everywhere, with their endearing traits of pedantry',
#   0.7695958258032375],
#  [[[84, 157], [636, 157], [636, 186], [84, 186]],
#   'generosity, integrity, and desire to use data in the best way possible',
#   0.5526486242746916]]

# %%
Image("eng3.jpeg")

# %%
out3 = reader.readtext("eng3.jpeg")

# %%
out3
# Out:
# [[[[19, 71], [118, 71], [118, 100], [19, 100]], 'Summary', 0.9089963640912491],
#  [[[30, 115], [535, 115], [535, 133], [30, 133]],
#   'Blnary variables are yeSInO qLBSUOnS, sels ol which can bo summnarized as proportions',
#   0.1565614802468843],
#  [[[31, 135], [477, 135], [477, 156], [31, 156]],
#   'PosIIIvD or negauva Iraming of proportons can change thair amotonal Impacl',
#   0.21583310532878935],
#  [[[31, 157], [639, 157], [639, 175], [31, 175]],
#   'Relativs risks tend to convey An exnggeraled Importance, and absoluts riels should bo provided Ior clarity',
#   0.1961681386950094],
#  [[[31, 178], [529, 178], [529, 195], [31, 195]],
#   'Expected Irequancles promole undarslanding anJ an appropriala sensa ol Imporlanca ',
#   0.2850023239407041],
#  [[[31, 197], [555, 197], [555, 217], [31, 217]],
#   'Oods ratos arisa from sclantific studlas bul shoud not be used for general communcation',
#   0.15450918195590943],
#  [[[31, 221], [431, 221], [431, 237], [31, 237]],
# ...

# %%
Image("eng4.jpeg")

# %%
out4 = reader.readtext("eng4.jpeg")

# %%
out4
# Out:
# [[[[347, 242], [647, 242], [647, 298], [347, 298]],
#   'Introduction',
#   0.6944831925617495],
#  [[[70, 450], [186, 450], [186, 474], [70, 474]],
#   'In several of',
#   0.8647529519927608],
#  [[[213, 446], [645, 446], [645, 482], [213, 482]],
#   'earlier Kogan Page titles I have provided readers',
#   0.6090962055364832],
#  [[[70, 476], [360, 476], [360, 504], [70, 504]],
#   'with the opportunity to obtain',
#   0.7776078505395189],
#  [[[378, 472], [644, 472], [644, 504], [378, 504]],
#   'greater understanding of IQ',
#   0.8645750422418177],
#  [[[68, 500], [644, 500], [644, 531], [68, 531]],
#   'testing by means of practice tests in which readers have been able',
#   0.5740695201984596],
#  [[[72, 527], [518, 527], [518, 556], [72, 556]],
#   'to familiarize themselves with the type of questions',
#   0.7805581374181548],
#  [[[558, 528], [644, 528], [644, 554], [558, 554]],
#   'are likely',
#   0.9938354148170747],
#  [[[72, 554], [390, 554], [390, 582], [72, 582]],
# ...

# %%
Image("eng5.jpeg")

# %%
out5 = reader.readtext("eng5.jpeg")

# %%
out5
# Out:
# [[[[69, 5], [645, 5], [645, 42], [69, 42]],
#   'their strengths and work at improving their performance in areas',
#   0.5757191283571708],
#  [[[70, 36], [184, 36], [184, 60], [70, 60]],
#   'of weakness ',
#   0.9699836951082385],
#  [[[92, 60], [644, 60], [644, 88], [92, 88]],
#   'Each test consists of 30 questions  The tests are all multidisci-',
#   0.5002309126298118],
#  [[[70, 87], [644, 87], [644, 116], [70, 116]],
#   'plinary, which provides the opportunity to practise on the range',
#   0.6938026139249626],
#  [[[70, 112], [580, 112], [580, 142], [70, 142]],
#   'of questions you are likely to encounter in actual IQ tests.',
#   0.6635449376522969],
#  [[[96, 140], [558, 140], [558, 164], [96, 164]],
#   'A time limit of 120 minutes is allowed for each test',
#   0.4611586068422592],
#  [[[564, 140], [644, 140], [644, 164], [564, 164]],
#   'Answers',
#   0.9983750291193173],
#  [[[70, 164], [644, 164], [644, 194], [70, 194]],
# ...

# %%
Image("eng6.jpeg")

# %%
out6 = reader.readtext("eng6.jpeg")
out6
# Out:
# [[[[70, 18], [644, 18], [644, 50], [70, 50]],
#   'their strengths and work at improving their performance in areas',
#   0.6569410208507172],
#  [[[70, 48], [184, 48], [184, 72], [70, 72]],
#   'of weakness ',
#   0.7515579208626489],
#  [[[92, 74], [644, 74], [644, 101], [92, 101]],
#   'Each test consists of 30 questions The tests are all multidisci-',
#   0.5641693222033063],
#  [[[70, 98], [427, 98], [427, 128], [70, 128]],
#   'plinary, which provides the opportunity',
#   0.7685620188550206],
#  [[[431, 107], [453, 107], [453, 123], [431, 123]], '[0', 0.7981902151452275],
#  [[[450, 98], [644, 98], [644, 128], [450, 128]],
#   'practise on the range',
#   0.999011108167026],
#  [[[70, 124], [580, 124], [580, 154], [70, 154]],
#   'of questions you are likely to encounter in actual IQ tests.',
#   0.7183456478348583],
#  [[[96, 152], [644, 152], [644, 176], [96, 176]],
#   'A time limit of 120 minutes is allowed for cach test Answers',
#   0.4253129334690402],
# ...

# %%
Image("eng7.jpeg")

# %%
out7 = reader.readtext("eng7.jpeg")
out7
# Out:
# [[[[521, 71], [613, 71], [613, 91], [521, 91]],
#   'Introduction',
#   0.5918167367229009],
#  [[[70, 126], [350, 126], [350, 154], [70, 154]],
#   'standardized test designed to',
#   0.44450496636821585],
#  [[[354, 126], [644, 126], [644, 154], [354, 154]],
#   'measure human intelligence as',
#   0.8007142269901729],
#  [[[70, 152], [416, 152], [416, 178], [70, 178]],
#   'distinct from attainments  Usually IQ',
#   0.3983588521153977],
#  [[[420, 152], [576, 152], [576, 176], [420, 176]],
#   'tests consist of a',
#   0.8484361255160274],
#  [[[574, 149], [645, 149], [645, 180], [574, 180]],
#   'graded',
#   0.8333929125418744],
#  [[[70, 176], [645, 176], [645, 207], [70, 207]],
#   'series of tasks, each of which has been standardized with a large',
#   0.9229022133585356],
#  [[[68, 199], [617, 199], [617, 235], [68, 235]],
#   'representative population of individuals in order to establish',
#   0.8267591197408569],
#  [[[619, 213], [643, 213], [643, 227], [619, 227]],
# ...

# %%
Image("eng9.jpeg")

# %%
out9 = reader.readtext("eng9.jpeg")
out9
# Out:
# [[[[103, 73], [237, 73], [237, 93], [103, 93]],
#   'Advonced |@ Iesis',
#   0.3499367100213545],
#  [[[68, 126], [644, 126], [644, 156], [68, 156]],
#   'practical prowess, especially if combined with personal charac-',
#   0.6403231789371219],
#  [[[68, 154], [190, 154], [190, 178], [68, 178]],
#   'teristics such',
#   0.9315243054595984],
#  [[[195, 161], [217, 161], [217, 177], [195, 177]], '5ق', 0.16290741876378717],
#  [[[217, 152], [310, 152], [310, 180], [217, 180]],
#   'ambition,',
#   0.9355487741996208],
#  [[[362, 154], [644, 154], [644, 183], [362, 183]],
#   'temperament and compassion,',
#   0.5886138380084286],
#  [[[68, 180], [210, 180], [210, 204], [68, 204]],
#   'could result in',
#   0.7454983174664102],
#  [[[217, 187], [241, 187], [241, 203], [217, 203]], '1اة', 0.1996945030032959],
#  [[[243, 176], [582, 176], [582, 209], [243, 209]],
#   'outstanding level of success despite',
#   0.6392958872604636],
#  [[[586, 180], [644, 180], [644, 204], [586, 204]],
# ...

# %% [markdown]
# # Text in wild

# %%
Image("s1.jpg")

# %%
ot1 = reader.readtext("s1.jpg")
ot1
# Out:
# []

# %%
Image("s2.jpg")

# %%
ot2 = reader.readtext("s2.jpg")
ot2
# Out:
# [[[[8, 64], [100, 64], [100, 90], [8, 90]], 'Jodamo', 0.685780843061235],
#  [[[127, 51], [271, 51], [271, 93], [127, 93]], 'Jodan o', 0.5067720014253813]]

# %%
Image("s3.jpg")

# %%
ot3 = reader.readtext("s3.jpg")
ot3
# Out:
# [[[[24, 18], [252, 18], [252, 48], [24, 48]],
#   'D E B E N H A M S',
#   0.2519014036031512]]

# %%
Image("s4.jpg")

# %%
out4 = reader.readtext("s4.jpg")
out4
# Out:
# [[[[43, 13], [231, 13], [231, 49], [43, 49]], 'PR|MARK', 0.5868046241865834]]

# %%
Image("s5.jpg")

# %%
ot5 = reader.readtext("s5.jpg")
ot5
# Out:
# [[[[60, 12], [108, 12], [108, 36], [60, 36]], 'TAKE', 0.9662712216377258],
#  [[[54, 30], [118, 30], [118, 60], [54, 60]], 'G٥R٤', 0.42892634868621826],
#  [[[60, 52], [110, 52], [110, 76], [60, 76]], 'STIY', 0.5845320224761963],
#  [[[54, 70], [116, 70], [116, 100], [54, 100]], 'SAFE', 0.8980773416576718]]

# %%
Image("s6.jpg")

# %%
ot6 = reader.readtext("s6.jpg")
ot6
# Out:
# [[[[61, 14], [244, 14], [244, 52], [61, 52]],
#   'رلت عصيب ولنو',
#   0.03481590741959418]]

# %%
Image("s7.jpg")

# %%
ot7 = reader.readtext("s7.jpg")
ot7
# Out:
# [[[[87, 57], [251, 57], [251, 99], [87, 99]],
#   'cool for school',
#   0.9812149612585416],
#  [[[313, 99], [343, 99], [343, 119], [313, 119]], 'A٧', 0.45487450407165875],
#  [[[275, 110], [374, 110], [374, 140], [275, 140]],
#   'MASK SIONY',
#   0.4011740800610511],
#  [[[429, 117], [528, 117], [528, 153], [429, 153]],
#   'CONVERSE)',
#   0.4655949735370421],
#  [[[569, 151], [611, 151], [611, 167], [569, 167]],
#   'الساا',
#   0.05945437234750566],
#  [[[53, 159], [79, 159], [79, 175], [53, 175]], '750', 0.6469414180697495],
#  [[[368, 254], [492, 254], [492, 282], [368, 282]],
#   'gettyimages',
#   0.6913338245109667],
#  [[[371, 279], [455, 279], [455, 293], [371, 293]],
#   'Anado Agensy',
#   0.5122939849244579],
#  [[[7, 387], [71, 387], [71, 401], [7, 401]],
#   '1230904091',
#   0.25479085333749085],
#  [[[40.07899166023172, 45.14487414671835],
#    [92.9005134665063, 55.2338266314889],
#    [87.92100833976828, 81.85512585328165],
# ...

# %%
Image("s8.jpg")

# %%
ot8 = reader.readtext("s8.jpg")
ot8
# Out:
# [[[[591, 73], [1015, 73], [1015, 209], [591, 209]], 'D٤', 0.27236276114139973],
#  [[[755, 457], [805, 457], [805, 471], [755, 471]],
#   'Z019,109',
#   0.03985285910857874],
#  [[[843, 463], [919, 463], [919, 475], [843, 475]],
#   'Voore٥dr',
#   0.026695537320576165],
#  [[[838, 512], [899, 512], [899, 528], [838, 528]],
#   'و و ال  ا٠ه ٣',
#   0.0004095944797773716],
#  [[[861, 557], [903, 557], [903, 571], [861, 571]],
#   'ولتظ',
#   0.013062077574431896],
#  [[[813.5143570688214, 458.12584272387846],
#    [845.9718501056888, 463.7643999743785],
#    [843.4856429311786, 477.87415727612154],
#    [811.0281498943112, 472.2356000256215]],
#   '7069',
#   0.08769732713699341],
#  [[[839.2928932188134, 535.2928932188134],
#    [870.9872411207126, 537.8407675611754],
#    [869.7071067811866, 546.7071067811866],
#    [838.0127588792874, 543.1592324388246]],
#   '٠٠ ٦ ٠٧',
#   0.012710802470878434]]

# %%
Image("s9.jpg")

# %%
ot9 = reader.readtext("s9.jpg")
ot9
# Out:
# [[[[167, 22], [826, 22], [826, 142], [167, 142]],
#   'PRIMARK',
#   0.9751927454098125],
#  [[[173, 287], [229, 287], [229, 307], [173, 307]],
#   '|9[٤',
#   0.04199448972940445]]

# %%
Image("s10.jpg")

# %%
ot10 = reader.readtext("s10.jpg")
ot10
# Out:
# [[[[496, 166], [756, 166], [756, 222], [496, 222]],
#   'ace & tate',
#   0.8388910886321445],
#  [[[394, 580], [502, 580], [502, 606], [394, 606]],
#   '٤١ ٤٣٤at=',
#   0.06243899866592401],
#  [[[503.21114561800016, 443.1055728090001],
#    [568.830172372132, 432.1934833614334],
#    [570.7888543819998, 449.8944271909999],
#    [506.169827627868, 459.8065166385666]],
#   '386182',
#   0.035653250068738554]]

# %%
Image("s11.jpg")

# %%
ot11 = reader.readtext("s11.jpg")
ot11
# Out:
# [[[[179, 43], [575, 43], [575, 91], [179, 91]],
#   'INTERNATIONAL',
#   0.5512973893260548],
#  [[[258, 95], [500, 95], [500, 133], [258, 133]],
#   'Mea 6Czhie',
#   0.0713501825777584]]

# %%
Image("s12.jpeg")

# %%
ot12 = reader.readtext("s12.jpeg")
ot12
# Out:
# [[[[204, 0], [344, 0], [344, 116], [204, 116]], '٤؟', 0.3850482592343688],
#  [[[1057, 309], [1083, 309], [1083, 329], [1057, 329]],
#   'T0',
#   0.6466533047942606],
#  [[[1239, 311], [1280, 311], [1280, 359], [1239, 359]],
#   ':P٥',
#   0.27557600985886427],
#  [[[819, 369], [857, 369], [857, 405], [819, 405]], '٧', 0.27385186482903023],
#  [[[1185, 545], [1251, 545], [1251, 617], [1185, 617]],
#   'آن',
#   0.15070269915338216],
#  [[[835, 619], [859, 619], [859, 635], [835, 635]],
#   '0٥٢',
#   0.15699517915356237],
#  [[[30, 613], [261, 613], [261, 725], [30, 725]], '0&6&', 0.09460385143756866],
#  [[[811, 719], [1015, 719], [1015, 833], [811, 833]],
#   '٤٨k 0٥',
#   0.06061277903083603],
#  [[[516, 723], [800, 723], [800, 898], [516, 898]], 'R0', 0.1691360558452698],
#  [[[355.4075772091337, -0.9882966089166452],
#    [1032.9745652599154, 159.12684750671048],
#    [994.5924227908663, 281.98829660891664],
#    [317.0254347400847, 120.87315249328952]],
#   'pounostretcngr',
# ...

# %%
Image("s13.jpeg")

# %%
ot13 = reader.readtext("s13.jpeg")
ot13
# Out:
# [([[649, 43], [669, 43], [669, 67], [649, 67]], '3', 0.16336242819372515),
#  ([[0, 104], [96, 104], [96, 208], [0, 208]], 'S', 0.9880783378978464),
#  ([[248, 70], [791, 70], [791, 246], [248, 246]],
#   'BETFRED',
#   0.9893517427480263),
#  ([[999, 123], [1079, 123], [1079, 185], [999, 185]],
#   'the',
#   0.9999909150374945),
#  ([[901, 168], [1082, 168], [1082, 241], [901, 241]],
#   'bonus',
#   0.9998590951725809),
#  ([[362, 296], [386, 296], [386, 324], [362, 324]], 'a', 0.9897053726008131),
#  ([[936, 228], [1082, 228], [1082, 328], [936, 328]],
#   '~king',
#   0.32372079519446656),
#  ([[1091, 319], [1170, 319], [1170, 356], [1091, 356]],
#   'BETERED',
#   0.7319319607798882),
#  ([[1143, 359], [1167, 359], [1167, 377], [1143, 377]],
#   'the',
#   0.9368779005090258),
#  ([[481, 367], [565, 367], [565, 387], [481, 387]],
#   'CHIP AND PIN',
#   0.599737576408752),
#  ([[481, 385], [549, 385], [549, 401], [481, 401]],
#   'AVAILABLE',
#   0.9916014913460351),
# ...
