# %% [markdown]
# <a href="https://colab.research.google.com/github/geehaad/OCR/blob/main/Copy_of_ArabicOCR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install ArabicOcr

# %%
from ArabicOcr import arabicocr

from google.colab.patches import cv2_imshow

# %%
#cv2_imshow(img)

# %%
import cv2
    
def detect(image_path,out_image):
    results=arabicocr.arabic_ocr(image_path,out_image)
    print(results)
    words=[]
    for i in range(len(results)):	
        word=results[i][1]
        words.append(word)
    with open ('file.txt','w',encoding='utf-8')as myfile:
        myfile.write(str(words))
    img = cv2.imread(out_image, cv2.IMREAD_UNCHANGED)
    cv2_imshow(img)

# %%
detect('img1.jpg','out1.jpg')
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# ...
# [INFO] OCR'ing input image...
# ...
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# [INFO] 0.6271: فيتثر   وهويسلم فيدور
# [INFO] 0.4684: "هاهي  اقرأها بنفسك " ، رد بيتر
# [INFO] 0.3067: الجريدة التي ماتزال رطبة من ضغطه عليها. كانت الكلمات محاطة
# [INFO] 0.5898: إيفانو
# ...

# %%
detect('img2.jpg','out2.jpg')
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# [INFO] OCR'ing input image...
# [INFO] 0.9391: لجريدة
# [[[[0, 22], [64, 22], [64, 54], [0, 54]], 'لجريدة', 0.9390736955276817]]
# <PIL.Image.Image image mode=RGB size=72x69 at 0x7F4FFCA22B50>

# %%
detect('img3.jpg','out3.jpg')
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# [INFO] OCR'ing input image...
# [INFO] 0.3884: "كلا ، لا تقل ذلك !"
# [[[[61, 25], [255, 25], [255, 69], [61, 69]], '"كلا ، لا تقل ذلك !"', 0.38839990098150784]]
# <PIL.Image.Image image mode=RGB size=290x89 at 0x7F4FDE776750>

# %%
detect('img4.jpg','out4.jpg')
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# [INFO] OCR'ing input image...
# [INFO] 0.9863: "!
# [INFO] 0.7148: "لقد مات إبفان إيليتش !
# [INFO] 0.7492: قال
# [INFO] 0.6256: "أيها السادةا
# [INFO] 0.8118: لا تقل ذلك !"
# [INFO] 0.5790: اكلاً
# [INFO] 0.9057: وهويسلم فيدور
# [INFO] 0.4331: "هاهي ء اقرأها بنفسك " رد بيتر إيفانوفيتشر
# [INFO] 0.7335: الجريدة الني ماتزال رطبة من ضغطه عليها. كانت الكلمات محاطة
# ...

# %%
detect('img5.jpg','out5.jpg')
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# [INFO] OCR'ing input image...
# [INFO] 0.5517: أثناء الاستراحة فيمحاكمة ميلفينسكي - بمجمع
# [INFO] 0.9896: شيبيك
# [INFO] 0.4929: المدعوون المدنيون والأعضاءفي حجرة إيجورو
# [INFO] 0.4113: الخاصة  حبث دارالحوار حول قضية كارسوفسكى الشهيرة. ذكر فيدور
# [INFO] 0.4986: وقال إيفان
# [INFO] 0.8743: خاضعة لنطاق محكمنه
# [INFO] 0.9434: فازيليفيتش بلباقة أنها
# [INFO] 0.4452: بيتر إيفانوفيتش أي موقف - حبث م
# [INFO] 0.7458: ببنما
# [INFO] 0.6565: إيجوروفيتش
# [INFO] 0.9764: الجازيت التي
# [INFO] 0.3402: يشارك منذ البداية فيالحوار  واكتفى بالنظر في
# [INFO] 0.9970: استلمها للتو
# [INFO] 0.9970: "!
# [INFO] 0.5303: "لقد مات إيفان إيليتش !
# [INFO] 0.8170: قال
# [INFO] 0.7233: "أيها السادة "
# [INFO] 0.4722: لا تقل ذلك !"
# [INFO] 0.5406: اكلاً
# [INFO] 0.9246: وهويسلم فيدور
# [INFO] 0.3557: هاهي   اقرأها بنفسك "  رد بيتر إيفانو
# [INFO] 0.6750: كانت الكلمات محاطة
# [INFO] 0.5359: الجريدة التي ماتزال رطبة من ضغطه عليها
# [INFO] 0.9985: 21
# ...
